# %%
#@test {"output": "ignore"}
print('Installing dependencies...')
# !apt-get update -qq && apt-get install -qq libfluidsynth1 fluid-soundfont-gm build-essential libasound2-dev libjack-dev
# !pip install -qU pyfluidsynth pretty_midi

# !pip install -qU magenta

# Hack to allow python to pick up the newly-installed fluidsynth lib. 
# This is only needed for the hosted Colab environment.
import ctypes.util
orig_ctypes_util_find_library = ctypes.util.find_library
def proxy_find_library(lib):
  if lib == 'fluidsynth':
    return 'libfluidsynth.so.1'
  else:
    return orig_ctypes_util_find_library(lib)
ctypes.util.find_library = proxy_find_library

print('Importing libraries and defining some helper functions...')
from google.colab import files

import magenta
import note_seq
import tensorflow

print('🎉 Done!')
print(magenta.__version__)
print(tensorflow.__version__)
# Out:
# Installing dependencies...
# Selecting previously unselected package fluid-soundfont-gm.
# (Reading database ... 155113 files and directories currently installed.)
# Preparing to unpack .../fluid-soundfont-gm_3.1-5.1_all.deb ...
# Unpacking fluid-soundfont-gm (3.1-5.1) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up fluid-soundfont-gm (3.1-5.1) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#      |████████████████████████████████| 5.6 MB 4.4 MB/s
#      |████████████████████████████████| 51 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 5.3 MB/s
#      |████████████████████████████████| 1.6 MB 23.5 MB/s
# ...

# %%
from note_seq.protobuf import music_pb2

three_little_birds = music_pb2.NoteSequence()

# Add the notes to the sequence.
three_little_birds.notes.add(pitch=62, start_time=0.0, end_time=0.5, velocity=80)
three_little_birds.notes.add(pitch=71, start_time=0.5, end_time=0.75, velocity=80)
three_little_birds.notes.add(pitch=71, start_time=0.75, end_time=1, velocity=80)
three_little_birds.notes.add(pitch=71, start_time=1, end_time=1.25, velocity=80)
three_little_birds.notes.add(pitch=71, start_time=1.25, end_time=1.5, velocity=80)
three_little_birds.notes.add(pitch=71, start_time=1.5, end_time=2, velocity=80)
three_little_birds.notes.add(pitch=71, start_time=2.5, end_time=2.75, velocity=80)
three_little_birds.notes.add(pitch=71, start_time=2.75, end_time=3, velocity=80)
three_little_birds.notes.add(pitch=60, start_time=3, end_time=3.25, velocity=80)
three_little_birds.notes.add(pitch=71, start_time=3.25, end_time=3.625, velocity=80)
three_little_birds.notes.add(pitch=69, start_time=3.625, end_time=4.125, velocity=80) 
three_little_birds.total_time = 4.125

three_little_birds.tempos.add(qpm=60);

# This is a colab utility method that visualizes a NoteSequence.
note_seq.plot_sequence(three_little_birds)

# This is a colab utility method that plays a NoteSequence.
note_seq.play_sequence(three_little_birds,synth=note_seq.fluidsynth)

# Here's another NoteSequence!
# Out:
#   <div class="bk-root" id="99c16293-1c4b-4c50-8eb0-bcf89848c06e" data-root-id="1002"></div>
# <div id="id_1"> </div>

# %%
from note_seq.protobuf import music_pb2

havana = music_pb2.NoteSequence()

# Add the notes to the sequence.
havana.notes.add(pitch=60, start_time=0.0, end_time=0.25, velocity=80)
havana.notes.add(pitch=64, start_time=0.25, end_time=0.50, velocity=80)
havana.notes.add(pitch=64, start_time=0.50, end_time=0.75, velocity=80)
havana.notes.add(pitch=60, start_time=0.75, end_time=1, velocity=80)
havana.notes.add(pitch=60, start_time=1, end_time=1.25, velocity=80)
havana.notes.add(pitch=69, start_time=1.25, end_time=1.50, velocity=80)
havana.notes.add(pitch=64, start_time=2, end_time=2.25, velocity=80)
havana.notes.add(pitch=62, start_time=2.25, end_time=2.5, velocity=80)
havana.notes.add(pitch=64, start_time=2.5, end_time=2.75, velocity=80)
havana.notes.add(pitch=65, start_time=2.75, end_time=3, velocity=80)
havana.notes.add(pitch=64, start_time=3, end_time=3.25, velocity=80) 
havana.notes.add(pitch=62, start_time=3.25, end_time=3.50, velocity=80) 
havana.notes.add(pitch=60, start_time=3.50, end_time=3.75, velocity=80) 
havana.notes.add(pitch=64, start_time=3.75, end_time=4, velocity=80) 
havana.notes.add(pitch=64, start_time=4, end_time=4.25, velocity=80) 
havana.notes.add(pitch=60, start_time=4.25, end_time=4.50, velocity=80) 
havana.notes.add(pitch=60, start_time=4.50, end_time=4.75, velocity=80) 
havana.notes.add(pitch=69, start_time=4.75, end_time=5, velocity=80)
havana.total_time = 5

havana.tempos.add(qpm=60);

# This is a colab utility method that visualizes a NoteSequence.
note_seq.plot_sequence(havana)

# This is a colab utility method that plays a NoteSequence.
note_seq.play_sequence(havana,synth=note_seq.fluidsynth)

# Here's another NoteSequence!
# Out:
#   <div class="bk-root" id="4bf890e7-a03c-468c-bf8a-a82cf55f7b26" data-root-id="1642"></div>
# <div id="id_6"> </div>

# %%
print('Downloading model bundle. This will take less than a minute...')
note_seq.notebook_utils.download_bundle('basic_rnn.mag', '/content/')

# Import dependencies.
from magenta.models.melody_rnn import melody_rnn_sequence_generator
from magenta.models.shared import sequence_generator_bundle
from note_seq.protobuf import generator_pb2
from note_seq.protobuf import music_pb2

# Initialize the model.
print("Initializing Melody RNN...")
bundle = sequence_generator_bundle.read_bundle_file('/content/basic_rnn.mag')
generator_map = melody_rnn_sequence_generator.get_generator_map()
melody_rnn = generator_map['basic_rnn'](checkpoint=None, bundle=bundle)
melody_rnn.initialize()

print('🎉 Done!')
# Out:
# ...
# Initializing Melody RNN...
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /tmp/tmpaq7r73o8/model.ckpt
# 🎉 Done!

# %%
# Model options. Change these to get different generated sequences! 

input_sequence = three_little_birds # the sequence that will be used
num_steps = 128 # num_steps is how long each melody will be in 16th steps (128 steps = 8 bars)
temperature = 1.5 # the higher the temperature the more random the sequence.

# Set the start time to begin on the next step after the last note ends.
last_end_time = (max(n.end_time for n in input_sequence.notes)
                  if input_sequence.notes else 0)
qpm = input_sequence.tempos[0].qpm #the tempo that is set before
seconds_per_step = 60.0 / qpm / melody_rnn.steps_per_quarter 
total_seconds = num_steps * seconds_per_step #equals end_time

generator_options = generator_pb2.GeneratorOptions()
generator_options.args['temperature'].float_value = temperature
generate_section = generator_options.generate_sections.add(
  start_time=last_end_time + seconds_per_step,
  end_time=total_seconds)

# Ask the model to continue the sequence.
sequence1 = melody_rnn.generate(input_sequence, generator_options)

note_seq.plot_sequence(sequence1)
note_seq.play_sequence(sequence1, synth=note_seq.fluidsynth)
# Out:
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -362.154083
#   <div class="bk-root" id="9217b152-748a-40af-945c-8a9c0e2a1c1a" data-root-id="1800"></div>
# <div id="id_7"> </div>

# %%
note_seq.sequence_proto_to_midi_file(sequence1, 'three_little_birds.mid')

files.download('three_little_birds.mid')

# %%
# Model options. Change these to get different generated sequences! 

input_sequence = havana # the sequence that will be used
num_steps = 64 # num_steps is how long each melody will be in 16th steps (64 steps = 4 bars)
temperature = 1.5 # the higher the temperature the more random the sequence.

# Set the start time to begin on the next step after the last note ends.
last_end_time = (max(n.end_time for n in input_sequence.notes)
                  if input_sequence.notes else 0)
qpm = input_sequence.tempos[0].qpm #the tempo that is set before
seconds_per_step = 60.0 / qpm / melody_rnn.steps_per_quarter 
total_seconds = num_steps * seconds_per_step #equals end_time

generator_options = generator_pb2.GeneratorOptions()
generator_options.args['temperature'].float_value = temperature
generate_section = generator_options.generate_sections.add(
  start_time=last_end_time + seconds_per_step,
  end_time=total_seconds)

# Ask the model to continue the sequence.
sequence1 = melody_rnn.generate(input_sequence, generator_options)

note_seq.plot_sequence(sequence1)
note_seq.play_sequence(sequence1, synth=note_seq.fluidsynth)
# Out:
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -168.142654
#   <div class="bk-root" id="5f8179c7-3b65-4c10-935d-4769f6026ed4" data-root-id="1968"></div>
# <div id="id_8"> </div>

# %%
note_seq.sequence_proto_to_midi_file(sequence1, 'havana.mid')

files.download('havana.mid')
